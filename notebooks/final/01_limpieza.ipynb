# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
#
# Para observar los datos y saber su estructura base

# %%
# Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "data/final/datos_2025.csv"
df = pd.read_csv(file)
df
# Out:
#             Fecha   Hora     O3  O3 8hrs   NO2    CO    SO2 PM-10 PM-2.5  \
# 0      2025-01-01  00:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 1      2025-01-01  01:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 2      2025-01-01  02:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 3      2025-01-01  03:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 4      2025-01-01  04:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# ...           ...    ...    ...      ...   ...   ...    ...   ...    ...
# 15955  2025-05-13  19:00  0.036      NaN  Mtto  0.55  0.001    38   D.I.
# 15956  2025-05-13  20:00  0.041      NaN  Mtto  0.63  0.001    56     36
# 15957  2025-05-13  21:00  0.022      NaN  Mtto  0.78  0.001    93     52
# 15958  2025-05-13  22:00  0.009      NaN  Mtto  0.93  0.001   104     69
# 15959  2025-05-13  23:00  0.003      NaN  Mtto  1.11  0.001   104     69
#
#       Estacion
# 0        santa
# 1        santa
# 2        santa
# 3        santa
# 4        santa
# ...        ...
# 15955      vel
# 15956      vel
# 15957      vel
# 15958      vel
# 15959      vel
#
# [15960 rows x 10 columns]

# %% [markdown]
# # Estructura del dataset:
#
# - Fecha y Hora están en columnas separadas.
#
# - Contaminantes registrados:
#
#     - O3 y O3_8hrs (ozono puntual y promedio móvil)
#     - NO2, CO, SO2
#     - PM-10, PM-2.5
#
# - Estacion indica el sitio de monitoreo (por ahora solo vemos santa).
#
# # Próximos pasos:
#
# - Combinar Fecha y Hora en una sola columna DateTime.
#
# - Convertir variables numéricas al tipo correcto (varias están como texto).
#
# - Verificar valores nulos y tipos de datos.
#
# - Iniciar el EDA con estadísticas descriptivas y calidad de datos.

# %%
df_clean = df.copy()

# %%
# Paso 1: Combinar Fecha y Hora en una sola columna DateTime
df_clean['DateTime'] = pd.to_datetime(df_clean['Fecha'] + ' ' + df_clean['Hora'], format='%Y-%m-%d %H:%M')

df_clean
# Out:
#             Fecha   Hora     O3  O3 8hrs   NO2    CO    SO2 PM-10 PM-2.5  \
# 0      2025-01-01  00:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 1      2025-01-01  01:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 2      2025-01-01  02:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 3      2025-01-01  03:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# 4      2025-01-01  04:00   F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.
# ...           ...    ...    ...      ...   ...   ...    ...   ...    ...
# 15955  2025-05-13  19:00  0.036      NaN  Mtto  0.55  0.001    38   D.I.
# 15956  2025-05-13  20:00  0.041      NaN  Mtto  0.63  0.001    56     36
# 15957  2025-05-13  21:00  0.022      NaN  Mtto  0.78  0.001    93     52
# 15958  2025-05-13  22:00  0.009      NaN  Mtto  0.93  0.001   104     69
# 15959  2025-05-13  23:00  0.003      NaN  Mtto  1.11  0.001   104     69
#
#       Estacion            DateTime
# 0        santa 2025-01-01 00:00:00
# 1        santa 2025-01-01 01:00:00
# 2        santa 2025-01-01 02:00:00
# 3        santa 2025-01-01 03:00:00
# 4        santa 2025-01-01 04:00:00
# ...        ...                 ...
# 15955      vel 2025-05-13 19:00:00
# 15956      vel 2025-05-13 20:00:00
# 15957      vel 2025-05-13 21:00:00
# 15958      vel 2025-05-13 22:00:00
# 15959      vel 2025-05-13 23:00:00
#
# [15960 rows x 11 columns]

# %%
# Paso 2: Eliminar columnas originales Fecha y Hora
df_clean.drop(columns=['Fecha', 'Hora'], inplace=True)
df_clean
# Out:
#           O3  O3 8hrs   NO2    CO    SO2 PM-10 PM-2.5 Estacion  \
# 0       F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.    santa
# 1       F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.    santa
# 2       F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.    santa
# 3       F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.    santa
# 4       F.O.      NaN  F.O.  F.O.   F.O.  F.O.   F.O.    santa
# ...      ...      ...   ...   ...    ...   ...    ...      ...
# 15955  0.036      NaN  Mtto  0.55  0.001    38   D.I.      vel
# 15956  0.041      NaN  Mtto  0.63  0.001    56     36      vel
# 15957  0.022      NaN  Mtto  0.78  0.001    93     52      vel
# 15958  0.009      NaN  Mtto  0.93  0.001   104     69      vel
# 15959  0.003      NaN  Mtto  1.11  0.001   104     69      vel
#
#                  DateTime
# 0     2025-01-01 00:00:00
# 1     2025-01-01 01:00:00
# 2     2025-01-01 02:00:00
# 3     2025-01-01 03:00:00
# 4     2025-01-01 04:00:00
# ...                   ...
# 15955 2025-05-13 19:00:00
# 15956 2025-05-13 20:00:00
# 15957 2025-05-13 21:00:00
# 15958 2025-05-13 22:00:00
# 15959 2025-05-13 23:00:00
#
# [15960 rows x 9 columns]

# %%
# Paso 3: Renombrar columnas para mayor claridad y  consistencia
df_clean.columns = ['O3', 'O3_8hrs', 'NO2', 'CO', 'SO2', 'PM10', 'PM2_5', 'Estacion', 'DateTime']
df_clean
# Out:
#           O3  O3_8hrs   NO2    CO    SO2  PM10 PM2_5 Estacion  \
# 0       F.O.      NaN  F.O.  F.O.   F.O.  F.O.  F.O.    santa
# 1       F.O.      NaN  F.O.  F.O.   F.O.  F.O.  F.O.    santa
# 2       F.O.      NaN  F.O.  F.O.   F.O.  F.O.  F.O.    santa
# 3       F.O.      NaN  F.O.  F.O.   F.O.  F.O.  F.O.    santa
# 4       F.O.      NaN  F.O.  F.O.   F.O.  F.O.  F.O.    santa
# ...      ...      ...   ...   ...    ...   ...   ...      ...
# 15955  0.036      NaN  Mtto  0.55  0.001    38  D.I.      vel
# 15956  0.041      NaN  Mtto  0.63  0.001    56    36      vel
# 15957  0.022      NaN  Mtto  0.78  0.001    93    52      vel
# 15958  0.009      NaN  Mtto  0.93  0.001   104    69      vel
# 15959  0.003      NaN  Mtto  1.11  0.001   104    69      vel
#
#                  DateTime
# 0     2025-01-01 00:00:00
# 1     2025-01-01 01:00:00
# 2     2025-01-01 02:00:00
# 3     2025-01-01 03:00:00
# 4     2025-01-01 04:00:00
# ...                   ...
# 15955 2025-05-13 19:00:00
# 15956 2025-05-13 20:00:00
# 15957 2025-05-13 21:00:00
# 15958 2025-05-13 22:00:00
# 15959 2025-05-13 23:00:00
#
# [15960 rows x 9 columns]

# %%
# Paso 4: Convertir columnas numericas al tipo float (algunas estan como string)
cols_numeric = ['O3', 'O3_8hrs', 'NO2', 'CO', 'SO2', 'PM10', 'PM2_5']
df_clean[cols_numeric] = df_clean[cols_numeric].apply(pd.to_numeric, errors='coerce')
df_clean.dtypes
# Out:
# O3                 float64
# O3_8hrs            float64
# NO2                float64
# CO                 float64
# SO2                float64
# PM10               float64
# PM2_5              float64
# Estacion            object
# DateTime    datetime64[ns]
# dtype: object

# %%
# Normalización de unidades: convertir de ppm a ppb para gases si es necesario
if df_clean['O3'].max() < 1:  # indica que están en ppm
    df_clean['O3'] *= 1000
    df_clean['O3_8hrs'] *= 1000
    df_clean['CO'] *= 100
    df_clean['NO2'] *= 1000
    df_clean['SO2'] *= 1000
    print("✅ Gases convertidos de ppm a ppb.")

# CO se suele reportar en ppm, normalmente no se convierte (opcional)
# PM10 y PM2.5 ya están en µg/m³, no necesitan cambios
# Out:
# ✅ Gases convertidos de ppm a ppb.

# %%
# Verificacion final y valores nulos
data_types = df_clean.dtypes
missing_values = df_clean.isnull().sum()

data_types, missing_values
# Out:
# (O3                 float64
#  O3_8hrs            float64
#  NO2                float64
#  CO                 float64
#  SO2                float64
#  PM10               float64
#  PM2_5              float64
#  Estacion            object
#  DateTime    datetime64[ns]
#  dtype: object,
#  O3           1739
#  O3_8hrs     15960
#  NO2          2399
#  CO           1976
#  SO2          2151
#  PM10         1939
#  PM2_5        3079
#  Estacion        0
#  DateTime        0
#  dtype: int64)

# %%
# Extraer componentes temporales
df_clean['Anio'] = df_clean['DateTime'].dt.year
df_clean['Mes'] = df_clean['DateTime'].dt.month
df_clean['Dia'] = df_clean['DateTime'].dt.day
df_clean['Hora'] = df_clean['DateTime'].dt.hour

# Verificar estaciones únicas
unique_stations = df_clean['Estacion'].unique()
station_counts = df_clean['Estacion'].value_counts()

unique_stations, station_counts
# Out:
# (array(['santa', 'bine', 'ninfas', 'utp', 'vel'], dtype=object),
#  Estacion
#  santa     3192
#  bine      3192
#  ninfas    3192
#  utp       3192
#  vel       3192
#  Name: count, dtype: int64)

# %%
# Guardar df_clean en un nuevo archivo CSV
import os

# Guardar archivo
file_path = 'app/data/times/datos_Clean_2025.csv'
df_clean.to_csv(file_path, index=False)

print(f"Archivo guardado en: {file_path}")
# Out:
# Archivo guardado en: app/data/times/datos_Clean_2025.csv
