# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
#
# Para observar los datos y saber su estructura base

# %%
# Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "data/Crudos/datos_2025.csv"
df = pd.read_csv(file)
df
# Out:
#             Fecha   Hora        O3  O3 8hrs       NO2        CO       SO2  \
# 0      2025-01-01  00:00      F.O.      NaN      F.O.      F.O.      F.O.
# 1      2025-01-01  01:00      F.O.      NaN      F.O.      F.O.      F.O.
# 2      2025-01-01  02:00      F.O.      NaN      F.O.      F.O.      F.O.
# 3      2025-01-01  03:00      F.O.      NaN      F.O.      F.O.      F.O.
# 4      2025-01-01  04:00      F.O.      NaN      F.O.      F.O.      F.O.
# ...           ...    ...       ...      ...       ...       ...       ...
# 17635  2025-05-27  19:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17636  2025-05-27  20:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17637  2025-05-27  21:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17638  2025-05-27  22:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17639  2025-05-27  23:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
#
#           PM-10    PM-2.5 Estacion
# 0          F.O.      F.O.    santa
# 1          F.O.      F.O.    santa
# 2          F.O.      F.O.    santa
# 3          F.O.      F.O.    santa
# 4          F.O.      F.O.    santa
# ...         ...       ...      ...
# 17635  Sin dato  Sin dato      vel
# 17636  Sin dato  Sin dato      vel
# 17637  Sin dato  Sin dato      vel
# 17638  Sin dato  Sin dato      vel
# 17639  Sin dato  Sin dato      vel
#
# [17640 rows x 10 columns]

# %% [markdown]
# # Estructura del dataset:
#
# - Fecha y Hora están en columnas separadas.
#
# - Contaminantes registrados:
#
#     - O3 y O3_8hrs (ozono puntual y promedio móvil)
#     - NO2, CO, SO2
#     - PM-10, PM-2.5
#
# - Estacion indica el sitio de monitoreo (por ahora solo vemos santa).
#
# # Próximos pasos:
#
# - Combinar Fecha y Hora en una sola columna DateTime.
#
# - Convertir variables numéricas al tipo correcto (varias están como texto).
#
# - Verificar valores nulos y tipos de datos.
#
# - Iniciar el EDA con estadísticas descriptivas y calidad de datos.

# %%
df_clean = df.copy()

# %%
# Paso 1: Combinar Fecha y Hora en una sola columna DateTime
df_clean['DateTime'] = pd.to_datetime(df_clean['Fecha'] + ' ' + df_clean['Hora'], format='%Y-%m-%d %H:%M')

df_clean
# Out:
#             Fecha   Hora        O3  O3 8hrs       NO2        CO       SO2  \
# 0      2025-01-01  00:00      F.O.      NaN      F.O.      F.O.      F.O.
# 1      2025-01-01  01:00      F.O.      NaN      F.O.      F.O.      F.O.
# 2      2025-01-01  02:00      F.O.      NaN      F.O.      F.O.      F.O.
# 3      2025-01-01  03:00      F.O.      NaN      F.O.      F.O.      F.O.
# 4      2025-01-01  04:00      F.O.      NaN      F.O.      F.O.      F.O.
# ...           ...    ...       ...      ...       ...       ...       ...
# 17635  2025-05-27  19:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17636  2025-05-27  20:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17637  2025-05-27  21:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17638  2025-05-27  22:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
# 17639  2025-05-27  23:00  Sin dato      NaN  Sin dato  Sin dato  Sin dato
#
#           PM-10    PM-2.5 Estacion            DateTime
# 0          F.O.      F.O.    santa 2025-01-01 00:00:00
# 1          F.O.      F.O.    santa 2025-01-01 01:00:00
# 2          F.O.      F.O.    santa 2025-01-01 02:00:00
# 3          F.O.      F.O.    santa 2025-01-01 03:00:00
# 4          F.O.      F.O.    santa 2025-01-01 04:00:00
# ...         ...       ...      ...                 ...
# 17635  Sin dato  Sin dato      vel 2025-05-27 19:00:00
# 17636  Sin dato  Sin dato      vel 2025-05-27 20:00:00
# 17637  Sin dato  Sin dato      vel 2025-05-27 21:00:00
# 17638  Sin dato  Sin dato      vel 2025-05-27 22:00:00
# 17639  Sin dato  Sin dato      vel 2025-05-27 23:00:00
#
# [17640 rows x 11 columns]

# %%
# Paso 2: Eliminar columnas originales Fecha y Hora
df_clean.drop(columns=['Fecha', 'Hora'], inplace=True)
df_clean
# Out:
#              O3  O3 8hrs       NO2        CO       SO2     PM-10    PM-2.5  \
# 0          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 1          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 2          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 3          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 4          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# ...         ...      ...       ...       ...       ...       ...       ...
# 17635  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17636  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17637  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17638  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17639  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
#
#       Estacion            DateTime
# 0        santa 2025-01-01 00:00:00
# 1        santa 2025-01-01 01:00:00
# 2        santa 2025-01-01 02:00:00
# 3        santa 2025-01-01 03:00:00
# 4        santa 2025-01-01 04:00:00
# ...        ...                 ...
# 17635      vel 2025-05-27 19:00:00
# 17636      vel 2025-05-27 20:00:00
# 17637      vel 2025-05-27 21:00:00
# 17638      vel 2025-05-27 22:00:00
# 17639      vel 2025-05-27 23:00:00
#
# [17640 rows x 9 columns]

# %%
# Paso 3: Renombrar columnas para mayor claridad y  consistencia
df_clean.columns = ['O3', 'O3_8hrs', 'NO2', 'CO', 'SO2', 'PM10', 'PM2_5', 'Estacion', 'DateTime']
df_clean
# Out:
#              O3  O3_8hrs       NO2        CO       SO2      PM10     PM2_5  \
# 0          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 1          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 2          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 3          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# 4          F.O.      NaN      F.O.      F.O.      F.O.      F.O.      F.O.
# ...         ...      ...       ...       ...       ...       ...       ...
# 17635  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17636  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17637  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17638  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
# 17639  Sin dato      NaN  Sin dato  Sin dato  Sin dato  Sin dato  Sin dato
#
#       Estacion            DateTime
# 0        santa 2025-01-01 00:00:00
# 1        santa 2025-01-01 01:00:00
# 2        santa 2025-01-01 02:00:00
# 3        santa 2025-01-01 03:00:00
# 4        santa 2025-01-01 04:00:00
# ...        ...                 ...
# 17635      vel 2025-05-27 19:00:00
# 17636      vel 2025-05-27 20:00:00
# 17637      vel 2025-05-27 21:00:00
# 17638      vel 2025-05-27 22:00:00
# 17639      vel 2025-05-27 23:00:00
#
# [17640 rows x 9 columns]

# %%
# Paso 4: Convertir columnas numericas al tipo float (algunas estan como string)
cols_numeric = ['O3', 'O3_8hrs', 'NO2', 'CO', 'SO2', 'PM10', 'PM2_5']
df_clean[cols_numeric] = df_clean[cols_numeric].apply(pd.to_numeric, errors='coerce')
df_clean.dtypes
# Out:
# O3                 float64
# O3_8hrs            float64
# NO2                float64
# CO                 float64
# SO2                float64
# PM10               float64
# PM2_5              float64
# Estacion            object
# DateTime    datetime64[ns]
# dtype: object

# %%
# Normalización de unidades: convertir de ppm a ppb para gases si es necesario
if df_clean['O3'].max() < 1:  # indica que están en ppm
    df_clean['O3'] *= 1000
    df_clean['O3_8hrs'] *= 1000
    df_clean['CO'] *= 100
    df_clean['NO2'] *= 1000
    df_clean['SO2'] *= 1000
    print("✅ Gases convertidos de ppm a ppb.")

# CO se suele reportar en ppm, normalmente no se convierte (opcional)
# PM10 y PM2.5 ya están en µg/m³, no necesitan cambios
# Out:
# ✅ Gases convertidos de ppm a ppb.

# %%
# Verificacion final y valores nulos
data_types = df_clean.dtypes
missing_values = df_clean.isnull().sum()

data_types, missing_values
# Out:
# (O3                 float64
#  O3_8hrs            float64
#  NO2                float64
#  CO                 float64
#  SO2                float64
#  PM10               float64
#  PM2_5              float64
#  Estacion            object
#  DateTime    datetime64[ns]
#  dtype: object,
#  O3           1897
#  O3_8hrs     17640
#  NO2          2612
#  CO           2233
#  SO2          2409
#  PM10         2155
#  PM2_5        3411
#  Estacion        0
#  DateTime        0
#  dtype: int64)

# %%
# Extraer componentes temporales
df_clean['Anio'] = df_clean['DateTime'].dt.year
df_clean['Mes'] = df_clean['DateTime'].dt.month
df_clean['Dia'] = df_clean['DateTime'].dt.day
df_clean['Hora'] = df_clean['DateTime'].dt.hour

# Verificar estaciones únicas
unique_stations = df_clean['Estacion'].unique()
station_counts = df_clean['Estacion'].value_counts()

unique_stations, station_counts
# Out:
# (array(['santa', 'bine', 'ninfas', 'utp', 'vel'], dtype=object),
#  Estacion
#  santa     3528
#  bine      3528
#  ninfas    3528
#  utp       3528
#  vel       3528
#  Name: count, dtype: int64)

# %%
# Guardar df_clean en un nuevo archivo CSV
import os

# Guardar archivo
file_path = 'data/Clean/datos_Clean_2025.csv'
df_clean.to_csv(file_path, index=False)

print(f"Archivo guardado en: {file_path}")
# Out:
# Archivo guardado en: data/Clean/datos_Clean_2025.csv
